# %% [markdown]
# <a href="https://colab.research.google.com/github/soniadumke/primeiro/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name "soniadumke"
# !git config --global user.email "soniaceciliadr@hotmail.com"
# !git config --global init.defaultBrant main
# !git config --global --list
# Out:
# git version 2.34.1
# user.name=soniadumke
# user.email=soniaceciliadr@hotmail.com
# init.defaultbrant=main

# %%
# !git clone https://github.com/soniadumke/primeiro.git
# Out:
# Cloning into 'primeiro'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %%writefile README.md
# #PCD - aula 3
# ##autor sonia
# Out:
# Writing README.md

# %%
# %cd primeiro/
# Out:
# /content/primeiro

# %%
# !git add README.md

# %%
# !git commit -m "Update class README"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !apt-get -qq update
# !apt-get -qq install gh
# !GH-PROMPT-DISABLED=1 gh auth login --hostname  github.com --github-protocol https --web
# !gh auth setup-git
# !gh auth status
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# /bin/bash: line 1: GH-PROMPT-DISABLED=1: command not found
# You are not logged into any GitHub hosts. Run gh auth login to authenticate.
# You are not logged into any GitHub hosts. To log in, run: gh auth login

# %%
# !git
