# %% [markdown]
# <a href="https://colab.research.google.com/github/soniadumke/primeiro/blob/main/media3var.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#atividade media valores
var1= float(input("informe um valor 1:"))
var2= float(input("informe um valor 2:"))
var3= float(input("informe um valor3:"))

media= (var1 + var2 + var3)/3
print(media)
# Out:
# informe um valor 1:2
# informe um valor 2:2
# informe um valor3:2
# 2.0
