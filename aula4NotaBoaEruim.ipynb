# %% [markdown]
# <a href="https://colab.research.google.com/github/soniadumke/primeiro/blob/main/aula4NotaBoaEruim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#nota boa e ruim
nota = float (input("digite o valor da nota:"))
if nota <60:
  print ("sua nota {} foi insuficiente!" .format(nota) )
else:
  print ("sua nota {} foi suficiente" .format(nota) )
# Out:
# digite o valor da nota:75
# sua nota 75.0 foi suficiente
