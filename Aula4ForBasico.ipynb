# %% [markdown]
# <a href="https://colab.research.google.com/github/soniadumke/primeiro/blob/main/Aula4ForBasico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#for basico usando range
for i in range (1, 10, 1):
  print (i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
